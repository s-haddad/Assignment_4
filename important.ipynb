# %%
install.packages("waffle")
install.packages("extrafont")
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
install.packages("extrafont")
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
library(waffle)
library(extrafont)
# Out:
# Loading required package: ggplot2
# Warning message:
# “S3 methods ‘[.fun_list’, ‘[.grouped_df’, ‘all.equal.tbl_df’, ‘anti_join.data.frame’, ‘anti_join.tbl_df’, ‘arrange.data.frame’, ‘arrange.default’, ‘arrange.grouped_df’, ‘arrange.tbl_df’, ‘arrange_.data.frame’, ‘arrange_.tbl_df’, ‘as.data.frame.grouped_df’, ‘as.data.frame.rowwise_df’, ‘as.data.frame.tbl_cube’, ‘as.data.frame.tbl_df’, ‘as.table.tbl_cube’, ‘as.tbl.data.frame’, ‘as.tbl.tbl’, ‘as.tbl_cube.array’, ‘as.tbl_cube.data.frame’, ‘as.tbl_cube.matrix’, ‘as.tbl_cube.table’, ‘as_data_frame.grouped_df’, ‘as_data_frame.tbl_cube’, ‘auto_copy.tbl_cube’, ‘auto_copy.tbl_df’, ‘cbind.grouped_df’, ‘collapse.data.frame’, ‘collect.data.frame’, ‘common_by.NULL’, ‘common_by.character’, ‘common_by.default’, ‘common_by.list’, ‘compute.data.frame’, ‘copy_to.DBIConnection’, ‘copy_to.src_local’, ‘default_missing.data.frame’, ‘default_missing.default’, ‘dim.tbl_cube’, ‘distinct.data.frame’, ‘distinct.default’, ‘distinct.grouped_df’, ‘distinct.tbl_df’, ‘distinct_.data.frame’, ‘distinct_.grouped_df’, ‘distinct_.tbl_df’, ‘do.NULL’, ‘do.data.frame’, ‘do.default’, ‘do.grouped_df’, ‘do.rowwise_df’, ‘do_.NULL’, ‘do_.data.frame’, ‘do_.grouped_df’, ‘do_.rowwise_df’, ‘filter.data.frame’, ‘filter.default’, ‘filter.tbl_cube’, ‘filter.tbl_df’, ‘filter.ts’, ‘filter_.data.frame’, ‘filter_.tbl_cube’, ‘filter_.tbl_df’, ‘format.src_local’, ‘full_join.data.frame’, ‘full_join.tbl_df’, ‘group_by.data.frame’, ‘group_by.default’, ‘group_by.rowwise_df’, ‘group_by.tbl_cube’, ‘group_by_.data.frame’, ‘group_by_.rowwise_df’, ‘group_by_.tbl_cube’, ‘group_indices.data.frame’, ‘group_indices.default’, ‘group_indices.grouped_df’, ‘group_indices_.data.frame’, ‘group_indices_.grouped_df’, ‘group_size.data.frame’, ‘group_size.grouped_df’, ‘group_size.rowwise_df’, ‘group_vars.default’, ‘group_vars.grouped_df’, ‘group_vars.tbl_cube’, ‘groups.data.frame’, ‘groups.grouped_df’, ‘groups.tbl_cube’, ‘inner_join.data.frame’, ‘inner_join.tbl_df’, ‘intersect.data.frame’, ‘intersect.default’, ‘left_join.data.frame’, ‘left_join.tbl_df’, ‘mutate.data.frame’, ‘mutate.default’, ‘mutate.tbl_df’, ‘mutate_.data.frame’, ‘mutate_.tbl_df’, ‘n_groups.data.frame’, ‘n_groups.grouped_df’, ‘n_groups.rowwise_df’, ‘print.BoolResult’, ‘print.all_vars’, ‘print.any_vars’, ‘print.fun_list’, ‘print.location’, ‘print.rowwise_df’, ‘print.src’, ‘print.tbl_cube’, ‘pull.data.frame’, ‘rbind.grouped_df’, ‘recode.character’, ‘recode.factor’, ‘recode.numeric’, ‘rename.data.frame’, ‘rename.default’, ‘rename.grouped_df’, ‘rename.tbl_cube’, ‘rename_.data.frame’, ‘rename_.grouped_df’, ‘rename_.tbl_cube’, ‘right_join.data.frame’, ‘right_join.tbl_df’, ‘same_src.data.frame’, ‘same_src.tbl_cube’, ‘sample_frac.data.frame’, ‘sample_frac.default’, ‘sample_frac.grouped_df’, ‘sample_n.data.frame’, ‘sample_n.default’, ‘sample_n.grouped_df’, ‘select.data.frame’, ‘select.default’, ‘select.grouped_df’, ‘select.tbl_cube’, ‘select_.data.frame’, ‘select_.grouped_df’, ‘select_.tbl_cube’, ‘semi_join.data.frame’, ‘semi_join.tbl_df’, ‘setdiff.data.frame’, ‘setdiff.default’, ‘setequal.data.frame’, ‘setequal.default’, ‘slice.data.frame’, ‘slice.default’, ‘slice.tbl_df’, ‘slice_.data.frame’, ‘slice_.tbl_df’, ‘src_tbls.src_local’, ‘summarise.data.frame’, ‘summarise.default’, ‘summarise.tbl_cube’, ‘summarise.tbl_df’, ‘summarise_.data.frame’, ‘summarise_.tbl_cube’, ‘summarise_.tbl_df’, ‘tbl.DBIConnection’, ‘tbl.src_local’, ‘tbl_sum.grouped_df’, ‘tbl_vars.data.frame’, ‘tbl_vars.tbl_cube’, ‘transmute.default’, ‘transmute.grouped_df’, ‘transmute_.default’, ‘transmute_.grouped_df’, ‘ungroup.data.frame’, ‘ungroup.grouped_df’, ‘ungroup.rowwise_df’, ‘union.data.frame’, ‘union.default’, ‘union_all.data.frame’, ‘union_all.default’ were declared in NAMESPACE but not found”Registering fonts with R

# %%
ttf_import(paths = NULL, recursive = TRUE, pattern = NULL)
# Out:
# Scanning ttf files in /Library/Fonts/, /System/Library/Fonts, ~/Library/Fonts/ ...
# Extracting .afm files from .ttf files...
# /Library/Fonts/Andale Mono.ttf : AndaleMono already registered in fonts database. Skipping.
# /Library/Fonts/Apple Chancery.ttfWarning message in system2(ttf2pt1, c(args, shQuote(ttfiles[i]), shQuote(tmpfiles[i])), :
# “running command ''/anaconda3/lib/R/library/Rttf2pt1/exec//ttf2pt1' -a -GfAe '/Library/Fonts/Apple Chancery.ttf' '/var/folders/43/pwprp2gd0s93kxq55xr5yq5c0000gn/T//RtmpGl0bv5/fonts/Apple Chancery' 2>&1' had status 1” : No FontName. Skipping.
# /Library/Fonts/AppleGothic.ttf : No FontName. Skipping.
# /Library/Fonts/AppleMyungjo.ttf : AppleMyungjo already registered in fonts database. Skipping.
# /Library/Fonts/Arial Black.ttf : Arial-Black already registered in fonts database. Skipping.
# /Library/Fonts/Arial Bold Italic.ttf : Arial-BoldItalicMT already registered in fonts database. Skipping.
# /Library/Fonts/Arial Bold.ttf : Arial-BoldMT already registered in fonts database. Skipping.
# /Library/Fonts/Arial Italic.ttf : Arial-ItalicMT already registered in fonts database. Skipping.
# /Library/Fonts/Arial Narrow Bold Italic.ttf : ArialNarrow-BoldItalic already registered in fonts database. Skipping.
# /Library/Fonts/Arial Narrow Bold.ttf : ArialNarrow-Bold already registered in fonts database. Skipping.
# /Library/Fonts/Arial Narrow Italic.ttf : ArialNarrow-Italic already registered in fonts database. Skipping.
# /Library/Fonts/Arial Narrow.ttf : ArialNarrow already registered in fonts database. Skipping.
# /Library/Fonts/Arial Rounded Bold.ttf : ArialRoundedMTBold already registered in fonts database. Skipping.
# /Library/Fonts/Arial Unicode.ttf : ArialUnicodeMS already registered in fonts database. Skipping.
# /Library/Fonts/Arial.ttf : ArialMT already registered in fonts database. Skipping.
# /Library/Fonts/Ayuthaya.ttf : No FontName. Skipping.
# /Library/Fonts/BigCaslon.ttf : No FontName. Skipping.
# /Library/Fonts/Bodoni 72 Smallcaps Book.ttf : BodoniSvtyTwoSCITCTT-Book already registered in fonts database. Skipping.
# /Library/Fonts/Bodoni Ornaments.ttf : BodoniOrnamentsITCTT already registered in fonts database. Skipping.
# /Library/Fonts/Bradley Hand Bold.ttf : Bradley-Hand-Bold already registered in fonts database. Skipping.
# /Library/Fonts/Brush Script.ttf : BrushScriptMT already registered in fonts database. Skipping.
# /Library/Fonts/Chalkduster.ttfWarning message in system2(ttf2pt1, c(args, shQuote(ttfiles[i]), shQuote(tmpfiles[i])), :
# “running command ''/anaconda3/lib/R/library/Rttf2pt1/exec//ttf2pt1' -a -GfAe '/Library/Fonts/Chalkduster.ttf' '/var/folders/43/pwprp2gd0s93kxq55xr5yq5c0000gn/T//RtmpGl0bv5/fonts/Chalkduster' 2>&1' had status 134” : No FontName. Skipping.
# /Library/Fonts/Comic Sans MS Bold.ttf : ComicSansMS-Bold already registered in fonts database. Skipping.
# /Library/Fonts/Comic Sans MS.ttf : ComicSansMS already registered in fonts database. Skipping.
# /Library/Fonts/Courier New Bold Italic.ttf : CourierNewPS-BoldItalicMT already registered in fonts database. Skipping.
# /Library/Fonts/Courier New Bold.ttf : CourierNewPS-BoldMT already registered in fonts database. Skipping.
# /Library/Fonts/Courier New Italic.ttf : CourierNewPS-ItalicMT already registered in fonts database. Skipping.
# /Library/Fonts/Courier New.ttf : CourierNewPSMT already registered in fonts database. Skipping.
# /Library/Fonts/DIN Alternate Bold.ttf : DINAlternate-Bold already registered in fonts database. Skipping.
# /Library/Fonts/DIN Condensed Bold.ttf : DINCondensed-Bold already registered in fonts database. Skipping.
# /Library/Fonts/Diwan Thuluth.ttf : No FontName. Skipping.
# /Library/Fonts/Farisi.ttf : No FontName. Skipping.
# /Library/Fonts/Georgia Bold Italic.ttf : Georgia-BoldItalic already registered in fonts database. Skipping.
# /Library/Fonts/Georgia Bold.ttf : Georgia-Bold already registered in fonts database. Skipping.
# /Library/Fonts/Georgia Italic.ttf : Georgia-Italic already registered in fonts database. Skipping.
# /Library/Fonts/Georgia.ttf : Georgia already registered in fonts database. Skipping.
# /Library/Fonts/Gungseouche.ttf : No FontName. Skipping.
# /Library/Fonts/Gurmukhi.ttf : No FontName. Skipping.
# /Library/Fonts/HeadlineA.ttfWarning message in system2(ttf2pt1, c(args, shQuote(ttfiles[i]), shQuote(tmpfiles[i])), :
# “running command ''/anaconda3/lib/R/library/Rttf2pt1/exec//ttf2pt1' -a -GfAe '/Library/Fonts/HeadlineA.ttf' '/var/folders/43/pwprp2gd0s93kxq55xr5yq5c0000gn/T//RtmpGl0bv5/fonts/HeadlineA' 2>&1' had status 1” : No FontName. Skipping.
# /Library/Fonts/Herculanum.ttf : No FontName. Skipping.
# /Library/Fonts/Hoefler Text Ornaments.ttf : No FontName. Skipping.
# /Library/Fonts/Impact.ttf : Impact already registered in fonts database. Skipping.
# /Library/Fonts/InaiMathi.ttf : No FontName. Skipping.
# /Library/Fonts/Khmer Sangam MN.ttf : KhmerSangamMN already registered in fonts database. Skipping.
# /Library/Fonts/Kokonor.ttfWarning message in system2(ttf2pt1, c(args, shQuote(ttfiles[i]), shQuote(tmpfiles[i])), :
# “running command ''/anaconda3/lib/R/library/Rttf2pt1/exec//ttf2pt1' -a -GfAe '/Library/Fonts/Kokonor.ttf' '/var/folders/43/pwprp2gd0s93kxq55xr5yq5c0000gn/T//RtmpGl0bv5/fonts/Kokonor' 2>&1' had status 134” : No FontName. Skipping.
# /Library/Fonts/Krungthep.ttf : No FontName. Skipping.
# /Library/Fonts/Lao Sangam MN.ttf : LaoSangamMN already registered in fonts database. Skipping.
# /Library/Fonts/Luminari.ttf : Luminari-Regular already registered in fonts database. Skipping.
# /Library/Fonts/Microsoft Sans Serif.ttf : MicrosoftSansSerif already registered in fonts database. Skipping.
# /Library/Fonts/Mishafi Gold.ttf : No FontName. Skipping.
# /Library/Fonts/Mishafi.ttf : No FontName. Skipping.
# /Library/Fonts/NISC18030.ttfWarning message in system2(ttf2pt1, c(args, shQuote(ttfiles[i]), shQuote(tmpfiles[i])), :
# “running command ''/anaconda3/lib/R/library/Rttf2pt1/exec//ttf2pt1' -a -GfAe '/Library/Fonts/NISC18030.ttf' '/var/folders/43/pwprp2gd0s93kxq55xr5yq5c0000gn/T//RtmpGl0bv5/fonts/NISC18030' 2>&1' had status 1” : No FontName. Skipping.
# /Library/Fonts/Osaka.ttfWarning message in system2(ttf2pt1, c(args, shQuote(ttfiles[i]), shQuote(tmpfiles[i])), :
# “running command ''/anaconda3/lib/R/library/Rttf2pt1/exec//ttf2pt1' -a -GfAe '/Library/Fonts/Osaka.ttf' '/var/folders/43/pwprp2gd0s93kxq55xr5yq5c0000gn/T//RtmpGl0bv5/fonts/Osaka' 2>&1' had status 1” : No FontName. Skipping.
# /Library/Fonts/OsakaMono.ttfWarning message in system2(ttf2pt1, c(args, shQuote(ttfiles[i]), shQuote(tmpfiles[i])), :
# “running command ''/anaconda3/lib/R/library/Rttf2pt1/exec//ttf2pt1' -a -GfAe '/Library/Fonts/OsakaMono.ttf' '/var/folders/43/pwprp2gd0s93kxq55xr5yq5c0000gn/T//RtmpGl0bv5/fonts/OsakaMono' 2>&1' had status 1” : No FontName. Skipping.
# /Library/Fonts/PCmyoungjo.ttfWarning message in system2(ttf2pt1, c(args, shQuote(ttfiles[i]), shQuote(tmpfiles[i])), :
# “running command ''/anaconda3/lib/R/library/Rttf2pt1/exec//ttf2pt1' -a -GfAe '/Library/Fonts/PCmyoungjo.ttf' '/var/folders/43/pwprp2gd0s93kxq55xr5yq5c0000gn/T//RtmpGl0bv5/fonts/PCmyoungjo' 2>&1' had status 1” : No FontName. Skipping.
# /Library/Fonts/Pilgiche.ttfWarning message in system2(ttf2pt1, c(args, shQuote(ttfiles[i]), shQuote(tmpfiles[i])), :
# “running command ''/anaconda3/lib/R/library/Rttf2pt1/exec//ttf2pt1' -a -GfAe '/Library/Fonts/Pilgiche.ttf' '/var/folders/43/pwprp2gd0s93kxq55xr5yq5c0000gn/T//RtmpGl0bv5/fonts/Pilgiche' 2>&1' had status 1” : No FontName. Skipping.
# /Library/Fonts/PlantagenetCherokee.ttf : No FontName. Skipping.
# /Library/Fonts/Sathu.ttf : No FontName. Skipping.
# /Library/Fonts/Silom.ttf : No FontName. Skipping.
# /Library/Fonts/Skia.ttfWarning message in system2(ttf2pt1, c(args, shQuote(ttfiles[i]), shQuote(tmpfiles[i])), :
# “running command ''/anaconda3/lib/R/library/Rttf2pt1/exec//ttf2pt1' -a -GfAe '/Library/Fonts/Skia.ttf' '/var/folders/43/pwprp2gd0s93kxq55xr5yq5c0000gn/T//RtmpGl0bv5/fonts/Skia' 2>&1' had status 1” : No FontName. Skipping.
# /Library/Fonts/Tahoma Bold.ttf : Tahoma-Bold already registered in fonts database. Skipping.
# /Library/Fonts/Tahoma.ttf : Tahoma already registered in fonts database. Skipping.
# /Library/Fonts/Times New Roman Bold Italic.ttf : TimesNewRomanPS-BoldItalicMT already registered in fonts database. Skipping.
# /Library/Fonts/Times New Roman Bold.ttf : TimesNewRomanPS-BoldMT already registered in fonts database. Skipping.
# /Library/Fonts/Times New Roman Italic.ttf : TimesNewRomanPS-ItalicMT already registered in fonts database. Skipping.
# /Library/Fonts/Times New Roman.ttf : TimesNewRomanPSMT already registered in fonts database. Skipping.
# /Library/Fonts/Trattatello.ttf : Trattatello already registered in fonts database. Skipping.
# /Library/Fonts/Trebuchet MS Bold Italic.ttf : Trebuchet-BoldItalic already registered in fonts database. Skipping.
# /Library/Fonts/Trebuchet MS Bold.ttf : TrebuchetMS-Bold already registered in fonts database. Skipping.
# /Library/Fonts/Trebuchet MS Italic.ttf : TrebuchetMS-Italic already registered in fonts database. Skipping.
# /Library/Fonts/Trebuchet MS.ttf : TrebuchetMS already registered in fonts database. Skipping.
# /Library/Fonts/Verdana Bold Italic.ttf : Verdana-BoldItalic already registered in fonts database. Skipping.
# /Library/Fonts/Verdana Bold.ttf : Verdana-Bold already registered in fonts database. Skipping.
# /Library/Fonts/Verdana Italic.ttf : Verdana-Italic already registered in fonts database. Skipping.
# /Library/Fonts/Verdana.ttf : Verdana already registered in fonts database. Skipping.
# /Library/Fonts/Webdings.ttf : Webdings already registered in fonts database. Skipping.
# /Library/Fonts/Wingdings 2.ttf : Wingdings2 already registered in fonts database. Skipping.
# /Library/Fonts/Wingdings 3.ttf : Wingdings3 already registered in fonts database. Skipping.
# /Library/Fonts/Wingdings.ttf : Wingdings-Regular already registered in fonts database. Skipping.
# /Library/Fonts/Zapfino.ttf : No FontName. Skipping.
# /Library/Fonts/儷宋 Pro.ttf : No FontName. Skipping.
# /Library/Fonts/儷黑 Pro.ttf : No FontName. Skipping.
# /Library/Fonts/华文仿宋.ttfWarning message in system2(ttf2pt1, c(args, shQuote(ttfiles[i]), shQuote(tmpfiles[i])), :
# “running command ''/anaconda3/lib/R/library/Rttf2pt1/exec//ttf2pt1' -a -GfAe '/Library/Fonts/华文仿宋.ttf' '/var/folders/43/pwprp2gd0s93kxq55xr5yq5c0000gn/T//RtmpGl0bv5/fonts/华文仿宋' 2>&1' had status 1” : No FontName. Skipping.
# /Library/Fonts/华文细黑.ttfWarning message in system2(ttf2pt1, c(args, shQuote(ttfiles[i]), shQuote(tmpfiles[i])), :
# “running command ''/anaconda3/lib/R/library/Rttf2pt1/exec//ttf2pt1' -a -GfAe '/Library/Fonts/华文细黑.ttf' '/var/folders/43/pwprp2gd0s93kxq55xr5yq5c0000gn/T//RtmpGl0bv5/fonts/华文细黑' 2>&1' had status 1” : No FontName. Skipping.
# /Library/Fonts/华文黑体.ttfWarning message in system2(ttf2pt1, c(args, shQuote(ttfiles[i]), shQuote(tmpfiles[i])), :
# “running command ''/anaconda3/lib/R/library/Rttf2pt1/exec//ttf2pt1' -a -GfAe '/Library/Fonts/华文黑体.ttf' '/var/folders/43/pwprp2gd0s93kxq55xr5yq5c0000gn/T//RtmpGl0bv5/fonts/华文黑体' 2>&1' had status 1” : No FontName. Skipping.
# /System/Library/Fonts/Apple Braille Outline 6 Dot.ttf : AppleBraille-Outline6Dot already registered in fonts database. Skipping.
# /System/Library/Fonts/Apple Braille Outline 8 Dot.ttf : AppleBraille-Outline8Dot already registered in fonts database. Skipping.
# /System/Library/Fonts/Apple Braille Pinpoint 6 Dot.ttf : AppleBraille-Pinpoint6Dot already registered in fonts database. Skipping.
# /System/Library/Fonts/Apple Braille Pinpoint 8 Dot.ttf : AppleBraille-Pinpoint8Dot already registered in fonts database. Skipping.
# /System/Library/Fonts/Apple Braille.ttf : AppleBraille already registered in fonts database. Skipping.
# /System/Library/Fonts/Apple Color Emoji.ttfWarning message in system2(ttf2pt1, c(args, shQuote(ttfiles[i]), shQuote(tmpfiles[i])), :
# “running command ''/anaconda3/lib/R/library/Rttf2pt1/exec//ttf2pt1' -a -GfAe '/System/Library/Fonts/Apple Color Emoji.ttf' '/var/folders/43/pwprp2gd0s93kxq55xr5yq5c0000gn/T//RtmpGl0bv5/fonts/Apple Color Emoji' 2>&1' had status 1” : No FontName. Skipping.
# /System/Library/Fonts/Keyboard.ttf : -Keyboard already registered in fonts database. Skipping.
# /System/Library/Fonts/LastResort.ttfWarning message in system2(ttf2pt1, c(args, shQuote(ttfiles[i]), shQuote(tmpfiles[i])), :
# “running command ''/anaconda3/lib/R/library/Rttf2pt1/exec//ttf2pt1' -a -GfAe '/System/Library/Fonts/LastResort.ttf' '/var/folders/43/pwprp2gd0s93kxq55xr5yq5c0000gn/T//RtmpGl0bv5/fonts/LastResort' 2>&1' had status 1” : No FontName. Skipping.
# /System/Library/Fonts/Symbol.ttf : No FontName. Skipping.
# /System/Library/Fonts/ZapfDingbats.ttf : No FontName. Skipping.
# /Users/selenahaddad/Library/Fonts/fontawesome-webfont.ttf : FontAwesome already registered in fonts database. Skipping.
# Found FontName for 0 fonts.
# Scanning afm files in /anaconda3/lib/R/library/extrafontdb/metrics
# Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FamilyName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FontName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^FullName", text):
# “input string 4 is invalid in this locale”Warning message in grepl("^Weight", text):
# “input string 4 is invalid in this locale”

# %%
fonts()[grep("Awesome", fonts())]
# Out:
# [1] "FontAwesome"

# %%
movies17 <- c(
  `Jan-Mar\n($2.508 billion)` = 2.5, `Apr-Jun\n($2.940 billion)` = 3,
  `Jul-Sep\n($2.054 billion)` = 2, `Oct-Dec\n($3.520 billion)` = 3.5)
waffle(
  movies17 / 0.25, rows = 3, size = 0.5, use_glyph = "ticket", glyph_size = 7, equal = TRUE, legend_pos = "bottom",
  colors = c("#071954", "#538054", "#FFB635", "#C5271C"),  title="Box Office Sales in 2017", 
       xlab="One ticket == $250 million") + theme(plot.title = element_text(size = 7), axis.title.x=element_text(size = 6), text=element_text(size = 6))
# Out:
# Warning message:
# “Removed 1 rows containing missing values (geom_text).”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font metrics unknown for character 0x4d”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”
# plot without title

# %%
pdf("assign4.pdf",useDingbats=FALSE,width=3.5,height=2,family='Helvetica')
movies17 <- c(
  `Jan-Mar\n($2.508 billion)` = 2.5, `Apr-Jun\n($2.940 billion)` = 3,
  `Jul-Sep\n($2.054 billion)` = 2, `Oct-Dec\n($3.520 billion)` = 3.5)
waffle(
  movies17 / 0.25, rows = 3, size = 0.5, use_glyph = "ticket", glyph_size = 7, equal = TRUE, legend_pos = "bottom",
  colors = c("#071954", "#538054", "#FFB635", "#C5271C"),  title="Box Office Sales in 2017", 
       xlab="One ticket == $250 million") + theme(plot.title = element_text(size = 7), axis.title.x=element_text(size = 6), text=element_text(size = 6))
dev.off()
embedFonts('assign4.pdf')
# Out:
# Warning message:
# “Removed 1 rows containing missing values (geom_text).”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font metrics unknown for character 0x4d”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# ...
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xb0”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x81”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x50”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0xff”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “font width unknown for character 0x7f”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <ef>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '' in 'mbcsToSbcs': dot substituted for <85>”
# pdf
#   2
